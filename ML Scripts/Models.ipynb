# %% [markdown]
# <a href="https://colab.research.google.com/github/nnilayy/Unet/blob/main/Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import binascii
import logging


mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# 60,000 training data and 10,000 test data of 28x28 pixel images
print("train_images shape", train_images.shape)
print("train_labels shape", train_labels.shape)
print("test_images shape", test_images.shape)
print("test_labels shape", test_labels.shape)

## Normalize the input image so that each pixel value is between 0 to 1.
train_images = train_images/255.0;
test_images = test_images/255.0;
train_labels = tf.keras.utils.to_categorical(train_labels, 10)
test_labels = tf.keras.utils.to_categorical(test_labels, 10)
print('Datasets are normalized')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, InputLayer, Reshape

model = Sequential()
model.add(InputLayer(input_shape=(28, 28)))
model.add(Reshape(target_shape=(28, 28, 1)))

# model.add(Conv2D(2, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
model.add(MaxPooling2D(2, padding='same'))
model.add(Conv2D(16, 3, padding='same', activation="relu"))
model.add(MaxPooling2D(2, padding='same'))
model.add(MaxPooling2D(2, padding='same'))

model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(BatchNormalization())
# model.add(Dropout(0.2))
model.add(Dense(10, activation="softmax"))
model.summary()




# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 63,182
# (2)Train Accuracy: 
# (2)Test Accuarcy: 0.983700
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(10, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))

# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 13,242
# (2)Train Accuracy: 0.9936
# (3)Test Accuarcy: 0.983700
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))

# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 6,674
# (2)Train Accuracy: 0.9798 
# (3)Test Accuarcy: 0.972700

# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 4,266
# (2)Train Accuracy: 0.9861 
# (3)Test Accuarcy: 0.980700
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))

# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 1,626
# (2)Train Accuracy: 0.9830 
# (3)Test Accuarcy:  0.979200
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# model.summary()
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 3,126
# (2)Train Accuracy: 0.9814 
# (3)Test Accuarcy:  0.978800
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(20, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# model.summary()
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 4,794
# (2)Train Accuracy: 0.9877 
# (3)Test Accuarcy:  0.978800
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# model.summary()
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 2,010
# (2)Train Accuracy: 0.9704 
# (3)Test Accuarcy:  0.967300
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 4,266
# (2)Train Accuracy: 0.9872 
# (3)Test Accuarcy:  0.983600
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details
# (1)Size: 4,266
# (2)Train Accuracy: 0.9872 
# (3)Test Accuarcy:  0.983600
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# Details

# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(6, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(6, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 2,118
# (2)Train Accuracy: 0.9853 
# (3)Test Accuarcy: 0.983200
# model.add(Conv2D(10, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 4,074
# (2)Train Accuracy: 0.9906
# (3)Test Accuarcy: 0.986000
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 7,434
# (2)Train Accuracy: 0.9921 
# (3)Test Accuarcy: 0.988900
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(Conv2D(32, 3, padding='same', activation="relu"))
# model.add(AveragePooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 4,474
# (2)Train Accuracy: 0.9905
# (3)Test Accuarcy: 0.987500
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(Conv2D(16, 3, padding='same', asctivation="relu"))
# model.add(AveragePooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 6,394
# (2)Train Accuracy: 0.9939 
# (3)Test Accuarcy: 0.987300
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(4, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(8, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 5,450
# (2)Train Accuracy: 0.9938
# (3)Test Accuarcy: 0.988400
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Flatten())
# model.add(Dense(10, activation="softmax"))
# ----------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------
# (1)Size: 7,210
# (2)Train Accuracy: 0.9952 
# (3)Test Accuarcy: 0.981400
# model = Sequential()
# model.add(InputLayer(input_shape=(28, 28)))
# model.add(Reshape(target_shape=(28, 28, 1)))

# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(Conv2D(16, 3, padding='same', activation="relu"))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))
# model.add(MaxPooling2D(2, padding='same'))

# model.add(Flatten())
# model.add(Dense(32, activation="relu"))
# model.add(Dense(10, activation="softmax"))
# Out:
# Model: "sequential_54"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  reshape_54 (Reshape)        (None, 28, 28, 1)         0
#
#  conv2d_130 (Conv2D)         (None, 28, 28, 16)        160
#
#  max_pooling2d_139 (MaxPooli  (None, 14, 14, 16)       0
#  ng2D)
#
#  conv2d_131 (Conv2D)         (None, 14, 14, 16)        2320
#
#  max_pooling2d_140 (MaxPooli  (None, 7, 7, 16)         0
#  ng2D)
#
#  max_pooling2d_141 (MaxPooli  (None, 4, 4, 16)         0
#  ng2D)
#
#  flatten_54 (Flatten)        (None, 256)               0
#
#  dense_74 (Dense)            (None, 10)                2570
#
# ...
# Total params: 5,050
# Trainable params: 5,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(train_images, train_labels, batch_size=128, epochs=30, verbose=1, validation_split=0.1)
# Out:
# Epoch 1/30
# 422/422 [==============================] - 4s 6ms/step - loss: 0.6042 - accuracy: 0.8226 - val_loss: 0.1497 - val_accuracy: 0.9565
# Epoch 2/30
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1522 - accuracy: 0.9540 - val_loss: 0.0930 - val_accuracy: 0.9718
# Epoch 3/30
# 422/422 [==============================] - 2s 4ms/step - loss: 0.1090 - accuracy: 0.9652 - val_loss: 0.0824 - val_accuracy: 0.9743
# Epoch 4/30
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0911 - accuracy: 0.9714 - val_loss: 0.0643 - val_accuracy: 0.9790
# Epoch 5/30
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0784 - accuracy: 0.9751 - val_loss: 0.0651 - val_accuracy: 0.9787
# Epoch 6/30
# 422/422 [==============================] - 2s 4ms/step - loss: 0.0713 - accuracy: 0.9773 - val_loss: 0.0585 - val_accuracy: 0.9813
# Epoch 7/30
# ...

# %%
test_loss, test_acc = model.evaluate(x=test_images, y=test_labels, verbose=1)
print('Accuracy = %f' % test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0395 - accuracy: 0.9875
# Accuracy = 0.987500

# %%
## Convert the Keras model to a quantized TFLite model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
def representative_dataset_gen():
   for i in range(100):
      input_image = tf.cast(test_images[i], tf.float32)
      input_image = tf.reshape(input_image, [1,28,28])
      yield ([input_image])

converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
tflite_model = converter.convert()
## Show the quantized model size in KBs.
tflite_model_size = len(tflite_model) / 1024
print('Quantized model size = %dKBs.' % tflite_model_size)
# Save the model to disk
open('qmodel.tflite', "wb").write(tflite_model)
